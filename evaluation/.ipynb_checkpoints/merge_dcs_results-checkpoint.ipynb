# %%
import pandas as pd

# %% [markdown]
# ## Merge data characteristics and regression results.

# %%
df_regression = pd.read_excel("../stats/final_table.xlsx")
bx_age = pd.read_csv("../stats/stats_BX_age.csv")
ml1m_age = pd.read_csv("../stats/stats_ml1m_age.csv")
ml1m_gender = pd.read_csv("../stats/stats_ml1m_gender.csv")

# %%
bx_age["Sensitive Feature"] = "Age"
ml1m_age["Sensitive Feature"] = "Age"
ml1m_gender["Sensitive Feature"] = "Gender"

# %%
# Convert columns to strings for consistent merging
columns_to_str = ['Dataset', 'Subset ID', 'Is Filtered', 'Sensitive Feature']

for col in columns_to_str:
    df_regression[col] = df_regression[col].astype(str)
    bx_age[col] = bx_age[col].astype(str)
    ml1m_age[col] = ml1m_age[col].astype(str)
    ml1m_gender[col] = ml1m_gender[col].astype(str)

# %%
df_regression.fillna(0, inplace=True)

# %%
df_final = df_regression.merge(
    bx_age, 
    how="left", 
    on=['Dataset', 'Subset ID', 'Is Filtered', 'Sensitive Feature']
)

# %%
df_final = df_regression.merge(
    bx_age, 
    how="left", 
    on=['Dataset', 'Subset ID', 'Is Filtered', 'Sensitive Feature']
)
df_final = df_final.merge(
    ml1m_age, 
    how="left", 
    on=['Dataset', 'Subset ID', 'Is Filtered', 'Sensitive Feature']
)

# %%
df_final
# Out:
#     Model Name Dataset Subset ID Is Filtered Sensitive Feature  ndcg@5  \
# 0         FOCF      BX         1         Yes               Age   0.189
# 1         FOCF      BX         2         Yes               Age   0.192
# 2         FOCF      BX         3         Yes               Age   0.209
# 3         FOCF      BX         4         Yes               Age   0.199
# 4         FOCF      BX         5         Yes               Age   0.190
# ..         ...     ...       ...         ...               ...     ...
# 727   PFCN_MLP    ml1m        59         Yes            Gender   0.046
# 728   PFCN_MLP    ml1m        60         Yes               Age   0.028
# 729   PFCN_MLP    ml1m        60         Yes            Gender   0.034
# 730   PFCN_MLP    ml1m        61         Yes               Age   0.221
# 731   PFCN_MLP    ml1m        61         Yes            Gender   0.224
#
#      recall@5  mrr@5  Differential Fairness of sensitive attribute  \
# 0       0.258  0.182                                         2.115
# 1       0.264  0.186                                         3.482
# 2       0.284  0.199                                         3.293
# 3       0.266  0.195                                         2.533
# 4       0.249  0.197                                         2.733
# ..        ...    ...                                           ...
# 727     0.076  0.039                                         2.459
# 728     0.026  0.047                                         3.812
# 729     0.044  0.034                                         3.666
# 730     0.302  0.229                                         2.549
# 731     0.307  0.234                                         2.337
#
#      giniindex@5  ...  Standart Deviation of Long Tail Items_y  \
# 0          0.941  ...                                      NaN
# 1          0.948  ...                                      NaN
# 2          0.942  ...                                      NaN
# 3          0.948  ...                                      NaN
# 4          0.955  ...                                      NaN
# ..           ...  ...                                      ...
# 727        0.949  ...                                      NaN
# 728        0.974  ...                                    0.141
# 729        0.971  ...                                      NaN
# 730        0.943  ...                                    0.176
# 731        0.945  ...                                      NaN
#
#      Skewness of Long Tail Items_y  Kurtosis of Long Tail Items_y  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# ..                             ...                            ...
# 727                            NaN                            NaN
# 728                          2.630                          9.510
# 729                            NaN                            NaN
# 730                          2.024                          5.011
# 731                            NaN                            NaN
#
#      Mean Rating_y  Standart Deviation of Rating_y  Skewness of Rating_y  \
# 0              NaN                             NaN                   NaN
# 1              NaN                             NaN                   NaN
# 2              NaN                             NaN                   NaN
# 3              NaN                             NaN                   NaN
# 4              NaN                             NaN                   NaN
# ..             ...                             ...                   ...
# 727            NaN                             NaN                   NaN
# 728          3.609                           1.137                -0.588
# 729            NaN                             NaN                   NaN
# 730          3.582                           1.117                -0.553
# 731            NaN                             NaN                   NaN
#
#      Kurtosis of Rating_y  Sensitive Attribute == 0 Percentage_y  \
# 0                     NaN                                    NaN
# 1                     NaN                                    NaN
# 2                     NaN                                    NaN
# 3                     NaN                                    NaN
# 4                     NaN                                    NaN
# ..                    ...                                    ...
# 727                   NaN                                    NaN
# 728                -0.354                                  25.19
# 729                   NaN                                    NaN
# 730                -0.350                                  22.35
# 731                   NaN                                    NaN
#
#      Sensitive Attribute == 1 Percentage_y  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 727                                    NaN
# 728                                  74.81
# 729                                    NaN
# 730                                  77.65
# 731                                    NaN
#
#      Difference between Sensitive Attribute Percentage_y
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 727                                                NaN
# 728                                              49.62
# 729                                                NaN
# 730                                              55.30
# 731                                                NaN
#
# [732 rows x 70 columns]
